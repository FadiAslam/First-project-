# %%
import matplotlib.pyplot as ply
import numpy as np

# %%
nums1=np.array([2,3,4,5,6,7,3663,7263,6153,5353,100,273,7,2,1])
nums2=np.array([12,34,26,100,77,6500,31,1])
nums3=np.array([10,20,3000,50,60,90,1000,50])
ply.plot(nums1,label="stock")
ply.plot(nums2,label="market")
ply.plot(nums3,label="consumer")
ply.legend()
ply.show()

# %%
students=np.array([5,20,5,6,8])
labels=np.array(["kasargod","kannur","malapuram","thrisur","ernakulam"])
ply.pie(students,labels=labels)
ply.show()

# %%
ply.bar(labels,students,color="purple")
# Out:
# <BarContainer object of 5 artists>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data_set = pd.read_csv("/content/drive/MyDrive/Copy of Salary_Data.csv")

# %%
print(data_set)
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
plt.plot(data_set["YearsExperience"],data_set["Salary"])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x=data_set["YearsExperience"]
y=data_set["Salary"]

# %%
x_train, x_test,y_train,y_test=train_test_split(x,y,test_size = 0.2)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x=data_set[["YearsExperience"]]
y=data_set[["Salary"]]
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
model.predict([[10]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[119836.51634753]])

# %%
num=float(input("enter the years of exp"))
arr = np.array([[num]])
print("predicted salary=",model.predict(arr))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-db8bedae4884> in <cell line: 1>()
# ----> 1 num=float(input("enter the years of exp"))
#       2 arr = np.array([[num]])
#       3 print("predicted salary=",model.predict(arr))
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %%
data_set = pd.read_csv("/content/drive/MyDrive/Copy of data_set.csv")

# %%
print(data_set)
# Out:
#               Timestamp  Height  Weight
# 0   13/09/2023 14:57:55     175      89
# 1   13/09/2023 14:58:02     170      50
# 2   13/09/2023 14:58:06     160      53
# 3   13/09/2023 14:58:07     179      76
# 4   13/09/2023 14:58:08     170      60
# 5   13/09/2023 14:58:14     176      59
# 6   13/09/2023 14:58:17     170      69
# 7   13/09/2023 14:58:19     173      66
# 8   13/09/2023 14:58:26     176      54
# 9   13/09/2023 14:58:32     153      46
# 10  13/09/2023 14:58:33     158      56
# 11  13/09/2023 14:58:42     157      45
# 12  13/09/2023 14:58:47     178      79
# 13  13/09/2023 14:59:00     180      91
# 14  13/09/2023 14:59:05     153      45
# 15  13/09/2023 14:59:17     179      62
# 16  13/09/2023 14:59:21     175      55
# 17  13/09/2023 14:59:21     152      45
# 18  13/09/2023 14:59:28     153      46
# 19  13/09/2023 14:59:55     170      49
# 20  13/09/2023 14:59:57     180      53
# 21  13/09/2023 14:59:59     175      61
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
x=data_set [["Height"]]
y=data_set [["Weight"]]
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(xtrain, ytrain)
# Out:
# LinearRegression()

# %%
model.predict([[170]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[61.27850647]])

# %%
plt.scatter(data_set["Height"],data_set["Weight"])
plt.show()
